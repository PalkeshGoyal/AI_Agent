# %%
from langchain_community.document_loaders import WebBaseLoader

# %%
url = "https://www.amazon.in/Samsung-Galaxy-Smartphone-Graphite-Storage/dp/B0DHL7YT5S/ref=sr_1_3?crid=X701R7YUQWZ4&dib=eyJ2IjoiMSJ9.0BWpZ4ImHW1ZfRnJShi1zg9k8jfEGY05v401fzX7EykONexPzMV9GsfuJiDinUQZf9T-gXWtP2jdesdDQCRznWhW6Qf7QnKsi823rkHlNl3B8ej6ADnUMl90y3UrxwsyMo-2V0G5rsDp0EKyig-r7A_GK_HnrhQz5bR85gVUuDKYS-attqjYk-50gIALXM4ylR9tmYSxi41PjSeKOxjzEm1mZMyQZ-tNIHMtwU8Q1Wo.NaDXb6wE159Ihi9Kn9ZG1kBTozZwMsIq_mYhkUkHnkg&dib_tag=se&keywords=samsung+s24+fe+5g&nsdOptOutParam=true&qid=1759230460&sprefix=samsung+%2Caps%2C247&sr=8-3"

# %%
web_loader = WebBaseLoader(url)

# %%
data = web_loader.load()

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    template="Answer the question on the basis of this : \nContent : {content}\nQuestion: {question}",
    input_variables=["question","content"],
)

# %%
chain = template | model | parser

# %%
while True:
    question = input("Ask something about S24 FE : ")
    if(question == "quit" or question == "exit"):
        break
    print(chain.invoke({"question" : question,"content" : data[0].page_content}))
# Out:
# The name of the product is **Samsung Galaxy S24 FE 5G AI Smartphone**.
# Based on the provided content, the CPU model used in the device is **Snapdragon**.
#
# It is listed under "About this item" as:
# *   **CPU Model: Snapdragon**
# *   **CPU Speed: 3.1 GHz**
#
# *(Note: Some customer reviews mention "Exynos," but the official product specifications list "Snapdragon".)*
# Based on the content, the Samsung Galaxy S24 FE 5G AI Smartphone supports:
#
# *   **Fast Charging Support** (mentioned in Special Features)
# *   **25W fast charging** (mentioned in customer reviews)
# *   It comes with a **Data Cable (Type C-to-C)**, indicating it uses a **USB Type-C** port for charging.

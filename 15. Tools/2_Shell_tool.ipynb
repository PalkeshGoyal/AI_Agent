# %%
from langchain.tools import ShellTool

# %%
shell_tool = ShellTool()

# %%
result = shell_tool.invoke("df -h")
print(result)
# Out:
# Executing command:
#  df -h
# Filesystem      Size  Used Avail Use% Mounted on
# tmpfs           1.5G  2.7M  1.5G   1% /run
# /dev/nvme0n1p7  173G  161G  3.0G  99% /
# tmpfs           7.5G  166M  7.3G   3% /dev/shm
# tmpfs           5.0M  4.0K  5.0M   1% /run/lock
# efivarfs        128K   49K   75K  40% /sys/firmware/efi/efivars
# tmpfs           7.5G     0  7.5G   0% /run/qemu
# /dev/nvme0n1p1  256M   38M  219M  15% /boot/efi
# tmpfs           1.5G  7.5M  1.5G   1% /run/user/1000
# /dev/nvme0n1p5  301G  211G   91G  71% /media/palkeshbsai/e_drive1
# /media/palkeshbsai/e_drive1/CampusX/GenAI using LangChain/venv/lib/python3.11/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

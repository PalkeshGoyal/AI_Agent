# %%
from langchain.tools import DuckDuckGoSearchRun

# %%
DDG_tool = DuckDuckGoSearchRun()

# %%
query = "Gold Price in India"

# %%
result = DDG_tool.invoke(query)
print(result)
# Out:
# 15 hours ago - Today's 18, 22 and 24 Carat Gold ... today, Wednesday, January 28 is ₹16,517 per gram for 24 karat gold, ₹15,140 per gram for 22 karat gold and ₹12,388 per gram for 18 karat gold .... 2 hours ago - Today's Gold Price per Gram in India is ₹15,628.58 INR . In the last 7 days, the price has risen significantly, showing an increase of ₹1,414.71 INR (9.95%). The current spot price is above the weekly average (₹14,888.46 INR). 7 hours ago - On 28 January 2026 the price of 24K gold in India is at ₹164,190 per 10 grams , while in Dubai it is ₹152,742, reflecting a difference of ₹11,448 or 7.50%. Similarly, 22K and 18K gold prices in India were also about 7.50% costlier compared ... 20 hours ago - In India, as of 08:22 AM on 28 January, gold prices stand at ₹16,194 per gram for 24K, ₹14,844 per gram for 22K, and ₹12,145 per gram for 18K . 6 days ago - Gold Rate in India Today: Check Gold Prices in India today for 22 and 24 carat in Delhi, Mumbai, Jaipur, and Indore Indian Major
# ...
